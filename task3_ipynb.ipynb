# %%
# Task 3 - Deep Dive Analysis & Interactive Dashboard

import pandas as pd
import matplotlib.pyplot as plt

# Sample Dataset
data = {
    "Customer": ["A", "B", "C", "D", "E"],
    "Sales": [5000, 7000, 4000, 6500, 8000],
    "Profit": [1200, 1800, 900, 1500, 2200],
    "Orders": [50, 70, 40, 65, 80]
}

df = pd.DataFrame(data)

# -------------------------------
# KPI Calculation
# -------------------------------
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
total_orders = df["Orders"].sum()
average_order_value = total_sales / total_orders

print("===== KEY PERFORMANCE INDICATORS =====")
print("Total Sales :", total_sales)
print("Total Profit :", total_profit)
print("Total Orders :", total_orders)
print("Average Order Value :", round(average_order_value, 2))

# -------------------------------
# Dashboard Charts
# -------------------------------

# Sales by Customer
plt.figure(figsize=(6,4))
plt.bar(df["Customer"], df["Sales"])
plt.title("Sales by Customer")
plt.xlabel("Customer")
plt.ylabel("Sales")
plt.show()

# Profit by Customer
plt.figure(figsize=(6,4))
plt.plot(df["Customer"], df["Profit"], marker="o")
plt.title("Profit by Customer")
plt.xlabel("Customer")
plt.ylabel("Profit")
plt.show()

# Sales Distribution
plt.figure(figsize=(5,5))
plt.pie(df["Sales"], labels=df["Customer"], autopct="%1.1f%%")
plt.title("Sales Distribution")
plt.show()
# Out:
# ===== KEY PERFORMANCE INDICATORS =====
# Total Sales : 30500
# Total Profit : 7600
# Total Orders : 305
# Average Order Value : 100.0
